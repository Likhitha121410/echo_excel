# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhitha121410/echo_excel/blob/main/data_analytics_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
marks = [20,30,50,100,30]
hours =[2,4,5,6,2]
print("mean:",np.mean(marks))
print("median:",np.median(marks))
print("mode:",pd.Series(marks).mode())
print("variance:",np.var(marks))
print("standard deviation:",np.std(marks))
print("corelation:",np.corrcoef(marks,hours))
# Out:
# mean: 46.0
# median: 30.0
# mode: 0    30
# dtype: int64
# variance: 824.0
# standard deviation: 28.705400188814647
# corelation: [[1.         0.85349794]
#  [0.85349794 1.        ]]
