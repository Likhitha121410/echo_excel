# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhitha121410/echo_excel/blob/main/e%20commers%20discriptive%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/exce2.csv")
print(data)
print("------------")

for i in range (len(data)):
  print(data.iloc[i])
  print("----------")
  print("------------------")
a=data[data["internet speed"]>=10]
print(a)
print("__________")
print("__________")
b=a[a["payment failuer"]<=3]
print(b)
print("_____________")
print("_____________")
c=b[b["del_charges"]<80]
print(c)
# Out:
#   cust name  internet speed  payment failuer  del_charges purchase compl
# 0      liki               5                2           60            yes
# 1      junn              10                5           70             no
# 2      mith              49                5           80             no
# 3     nandu              41                3           80            yes
# 4   shalini              45                2           77            yes
# ------------
# cust name          liki
# internet speed        5
# payment failuer       2
# del_charges          60
# purchase compl      yes
# Name: 0, dtype: object
# ----------
# ------------------
# cust name          junn
# internet speed       10
# payment failuer       5
# del_charges          70
# purchase compl       no
# Name: 1, dtype: object
# ----------
# ------------------
# cust name          mith
# internet speed       49
# payment failuer       5
# del_charges          80
# purchase compl       no
# Name: 2, dtype: object
# ...

# %%
import matplotlib.pyplot as plt
#bar chart
plt.bar(data['internet speed'],data['payment failuer'])
plt.xlabel('internet speed')
plt.ylabel('payment failuer')
plt.title('internet speed vs payment failuer')
plt.show()
print("            ")
# scatter plot
plt.scatter(data['internet speed'],data['payment failuer'])
plt.xlabel('internet speed')
plt.ylabel('payment failuer')
plt.title('internet speed vs payment failuer')
plt.show()
print("     ")

# pie chart
plt.figure(figsize=(7,7))

plt.pie(
    data['payment failuer'],
    labels=data['internet speed'],
    autopct='%1.1f%%',
    startangle=90,
    shadow=True
)

plt.title('internet speed vs payment failuer')
plt.show()
